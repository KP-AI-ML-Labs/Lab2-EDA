# %% [markdown]
# # Lab 2: Finding the Story - Exploratory Data Analysis (EDA)
#
# **Student Name:** [Your Name]
# **Roll Number:** [Your Roll Number]

# %% [markdown]
# ### 📖 Story Point
# Now that we have clean data, let's find the patterns within it. As data scientists, our next step is to perform Exploratory Data Analysis (EDA). We need to visualize the data to understand the performance of players and the dynamics of an innings. What does a typical T20 innings look like? Who are the star performers? Visualizations will help us answer these questions.

# %% [markdown]
# ### 🎯 Objective
# Visualize key aspects of the innings to derive initial insights using `pandas`, `matplotlib`, and `seaborn`.

# %% [markdown]
# ### ✅ In-Class Tasks

# %% [markdown]
# #### Task 1: Setup and Load Data
# Import `pandas`, `matplotlib.pyplot`, and `seaborn`. Load the `first_innings_batsmen.csv` file into a DataFrame.

# %% [markdown]
# #### Task 2: Bar Chart of Runs per Batsman
# Create a bar chart to visualize the **runs scored** by each batsman. Only include batsmen who actually batted (i.e., `didNotBat` is `False`).

# %% [markdown]
# #### Task 3: Scatter Plot of Balls vs. Runs
# Create a scatter plot of **Balls Faced vs. Runs Scored**. This will give us a visual cue about the strike rate of different players. Use `seaborn` for this plot.

# %% [markdown]
# #### Task 4: Histogram of Runs
# Generate a histogram of the runs scored by the batsmen who batted. This helps us understand the distribution of scores.

# %% [markdown]
# ### Deliverables
# A notebook containing at least 3 distinct visualizations with appropriate titles, labels, and a brief interpretation for each.

# %% [markdown]
# ---

# %% [markdown]
# ### 🏡 Home Task Extension
# The `wormAndManhattan` data in the original JSON is perfect for visualizing the flow of the game, over by over. Your task is to parse this data and create a **Worm Graph** showing the cumulative score progression.
#
# **Your Task:**
# 1. Load the original `get_scorecard.json` file.
# 2. Navigate to the `wormAndManhattan` list.
# 3. Create a new DataFrame with columns: `overNumber`, `cumulativeScore`, `wicketsInOver`.
# 4. You will need to parse the `firstInnings` string for each over (e.g., `"4,1,69,1"` means runs-in-over, wickets-in-over, cumulative-score, cumulative-wickets).
# 5. Create a line plot of `overNumber` vs. `cumulativeScore` for the first 20 overs.
